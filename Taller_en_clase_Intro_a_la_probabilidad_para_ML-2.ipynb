# %% [markdown]
# # Taller en clase #1
# Generando numeros aleatorios en ptython.
# Objetivos:
# 1. Familiarizar al estudiante con la generación de numeros aleatorios de diferentes distribuciones en python.
# 2. Usar las herramientas de python de manejo de arreglos.
# 3. Usar las herramientas de generación de gráficas de python.
# ## Entrega
# En U-virtual, antes de la siguiente clase en el link designado como Taller en clase 1.

# %%
import numpy  as np# si no lo tiene instalado por favor correr en su consola         $pip install numpy
import scipy as sp# si no lo tiene instalado por favor correr en su consola         $pip install scipy
import matplotlib #si no lo tiene instalado por favor correr  en su consola   $pip install matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Primer punto Distribuciones discretas.
# 1. Cree un arreglo de N muestras con N a su selección, pero mayor a 1000, de números distribuidos con las correspondientes distribuciones, para cada arreglo de números:
# 1. Grafique los números aleatorios,
# 2. Ordene de menor a mayor y grafique,
# 4. Encuentre los valores teoricos de media y varianza, y comparelos con los estimados.

# %%
#Para todas las simulaciones:
N=1000
m=30
numpy.random.seed(seed=2**32 - 1)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# bernoulli con cierto p entre 0 y 1
p=0.3
from scipy.stats import bernoulli
mean, var, skew, kurt = bernoulli.stats(p, moments='mvsk')
r = bernoulli.rvs(p, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli ordenados con p="+str(p))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la bernoulli con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la bernoulli con p= 0.3 son u= 0.3 var= 0.21
# Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p= 0.3 son u_est= 0.308 var_est= 0.21313599999999996

# %%
# binomial con cierto p entre 0 y 1 y cierto n
n,p = 10, 0.5
from scipy.stats import binom
mean, var, skew, kurt = binom.stats(n, p, moments='mvsk')
r=binom.rvs(n,p,size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos binomiales con p="+str(p))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos binomiales ordenados con p="+str(p))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos binomiales con p="+str(p))
plt.show()
print("Tipo de arreglo r:")
print(type(r))
print("Estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la binomial con p=",p,"y n=",n,"son u=" ,mean,"var=",var)
print("Los valores estimados en el experimento de la media y varianza para la binomial con p=",p,"y n=",n,"son u_est=",avg,"var_est=",varest)
# Out:
# Tipo de arreglo r:
# <class 'numpy.ndarray'>
# Estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la bernoulli con p= 0.5 son u= 5.0 var= 2.5
# Los valores estimados en el experimento de la media y varianza para la binomial con p= 0.5 y n= 10 son u_est= 4.939 var_est= 2.4312789999999995

# %%
# Geométrica con cierto p entre 0 y 1
p = 0.3
from scipy.stats import geom
mean, var, skew, kurt = geom.stats(p, moments='mvsk')
r = geom.rvs(p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos geometricamenteo con p="+str(p))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos geometricamente ordenados con p="+str(p))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos geometricamente con p="+str(p))
plt.show()
print("Tipo de nuestro arreglo r:")
print(type(r))
print("Estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la geometrica con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la geometrica con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la geometrica con p= 0.3 son u= 3.3333333333333335 var= 7.777777777777779
# Los valores estimados en nuestro experimento de la media y varianza para la geometrica con p= 0.3 son u_est= 3.287 var_est= 6.504631

# %%
# Poisson con cierto Lamnda L
L = 5
from scipy.stats import poisson
mean, var, skew, kurt = poisson.stats(L, moments='mvsk')
r = poisson.rvs(L, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli ordenados con p="+str(p))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos poisson con p="+str(p))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la poisson con L=",L,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la poissn con L=",L,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la poisson con L= 5 son u= 5.0 var= 5.0
# Los valores estimados en nuestro experimento de la media y varianza para la poissn con L= 5 son u_est= 4.907 var_est= 4.888350999999998

# %%
#Binomial negativa con parametro p después de r fallos
r,p = 5,0.5
from scipy.stats import nbinom
mean, var, skew, kurt = nbinom.stats(r, p, moments='mvsk')
rand=nbinom.rvs(r,p,size=N)
plt.plot(rand)
plt.title(str(N)+" puntos distribuidos binomiales con p="+str(p))
plt.show()
rand.sort()
plt.plot(rand)
plt.title(str(N)+" puntos distribuidos binomiales ordenados con p="+str(p)+" y r="+str(r))
plt.show()
plt.hist(rand, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos binomiales con p="+str(p))
plt.show()
print("Tipo de arreglo rand:")
print(type(rand))
print("Estimaciones de estadisticas de rand")
avg=rand.mean()
varest=rand.var()
print("Los valores teoricos de la media y varianza para la binomial negativa con p=",p,"y r=",r,"son u=" ,mean,"var=",var)
print("Los valores estimados en el experimento de la media y varianza para la binomial con p=",p,"y r=",r,"son u_est=",avg,"var_est=",varest)
# Out:
# Tipo de arreglo rand:
# <class 'numpy.ndarray'>
# Estimaciones de estadisticas de rand
# Los valores teoricos de la media y varianza para la binomial negativa con p= 0.5 y r= 5 son u= 5.0 var= 10.0
# Los valores estimados en el experimento de la media y varianza para la binomial con p= 0.5 y r= 5 son u_est= 4.97 var_est= 10.413100000000002

# %% [markdown]
# ## Segundo punto Distribuciones contínuas.

# %%
#Para todas las simulaciones:
N=1000
m=30
np.random.seed(seed=0)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# Normal de media 5 y desviación estandar 0.5
u=5
std=0.5
mean, var, skew, kurt = scipy.stats.norm.stats(moments='mvsk',loc=u,scale=std)
r = scipy.stats.norm.rvs (loc=u,scale=std, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales con media="+str(u)+" y std="+str(std))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales ordenados con p="+str(p))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos normales con u="+str(u)+ " y std= "+str(std))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la normal son u= 5.0 var= 0.25
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 4.984891109189428 var_est= 0.24349428191669814

# %%
# Uniforme entre 0 y 255
loc=0
scale=255
from scipy.stats import uniform
mean, var, skew, kurt = scipy.stats.uniform.stats(loc,scale,moments='mvsk')
r = scipy.stats.uniform.rvs (loc,scale, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos uniformemente entre"+str(loc)+" y "+str(scale))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos uniformemente ordenados entre"+str(loc)+" y "+str(scale))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos uniformemente entre"+str(loc)+" y "+str(scale))
plt.show()
print("Tipo de nuestro arreglo r:")
print(type(r))
print("Estimaciones de estadisticas de r") 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la normal son u= 127.5 var= 5418.75
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 128.71872491422573 var_est= 5127.999451695094

# %%
#T de Student con paramero K 
K=1.0
mean, var, skew, kurt = scipy.stats.t.stats(K,moments='mvsk')
r = scipy.stats.t.rvs (K, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos T de student con k="+str(K))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos T de student ordenados con k="+str(k))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos T de student con k="+str(k))
plt.show()
print("Tipo de nuestro arreglo r:")
print(type(r))
print("Estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la T son u=" ,mean,"var=",var)
print("Los valores estimados en el experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la normal son u= inf var= nan
# Los valores estimados en el experimento de la media y varianza son u_est= 0.0257456952810644 var_est= 213.7515016577922

# %%
# Exponencial con Lamnda L
L=0.3
mean, var, skew, kurt = scipy.stats.expon.stats(scale=1/L, moments='mvsk')
r = scipy.stats.expon.rvs (scale=1/L, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos exponencialmente con lambda="+str(L))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos exponencialmente ordenados")
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos exponencialmente con Lambda="+str(L))
plt.show()
print("Tipo de nuestro arreglo r:")
print(type(r))
print("Estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la exponencial son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la normal son u= 3.3333333333333335 var= 11.111111111111112
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 3.3574356195228496 var_est= 12.044345254826862

# %%
#Chi cuadrada con K grados de libertad
K=3.0
mean, var, skew, kurt = scipy.stats.chi2.stats(K, moments='mvsk')
r = scipy.stats.chi2.rvs (K, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos con chi cuadrada con "+str(K)+" grados de libertad")
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos ordenados")
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos con chi cuadrada con "+str(k)+" grados de libertad")
plt.show()
print("Tipo de nuestro arreglo r:")
print(type(r))
print("Estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la chi cuadrada son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la chi cuadrada son u= 3.0 var= 6.0
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 3.0351388675227167 var_est= 5.48919018844224

# %%
#Gamma con parametros k y theta t
k,t=2.54,0.43
mean, var, skew, kurt = scipy.stats.gamma.stats(k,scale=1/t, moments='mvsk')
r = scipy.stats.gamma.rvs (k,scale=1/t, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos con gamma con k="+str(k)+" y t="+str(t))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos ordenados")
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos con gamma con k="+str(k)+" y t="+str(t))
plt.show()
print("Tipo de nuestro arreglo r:")
print(type(r))
print("Estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la gamma son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la gamma son u= 5.906976744186047 var= 13.73715521903732
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 5.827751750567173 var_est= 13.098693970730379
